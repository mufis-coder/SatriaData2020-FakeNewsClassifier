# %%
from google.colab import drive
 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/gdrive/My Drive/BDC SD/data_kata_csv.csv')
df.head()
# Out:
#     lema  ...           type;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 0    -an  ...                Bentuk terikat;;;;;;;;;;;;
# 1  -anda  ...  Bentuk terikat;;;;;;;;;;;;;;;;;;;;;;;;;;
# 2   -asi  ...  Bentuk terikat;;;;;;;;;;;;;;;;;;;;;;;;;;
# 3    -da  ...  Bentuk terikat;;;;;;;;;;;;;;;;;;;;;;;;;;
# 4   -el-  ...      Bentuk terikat;;;;;;;;;;;;;;;;;;;;;;
#
# [5 rows x 4 columns]

# %%
df.lema.value_counts()
# Out:
# montit          1
# perbentrokan    1
# Hinayana        1
# mencandu        1
# arit            1
#                ..
# sepang          1
# menghibur       1
# sepatu          1
# zinkografi      1
# celengkang      1
# Name: lema, Length: 72252, dtype: int64

# %%
df_lema = df.lema

# %%
df_k = pd.read_excel('/content/gdrive/My Drive/BDC SD/jumlah_kata_train.xlsx')
df_k.head()
# Out:
#         kata  jumlah
# 0         yg     802
# 1  indonesia     749
# 2     jokowi     580
# 3         di     577
# 4       foto     495

# %%
df_k = df_k.assign(in_df=df_k.kata.isin(df.lema).astype(int))
df_k.head()
# Out:
#         kata  jumlah  in_df
# 0         yg     802      0
# 1  indonesia     749      0
# 2     jokowi     580      0
# 3         di     577      1
# 4       foto     495      1

# %%
df_k.in_df.value_counts()
# Out:
# 0    13931
# 1     7304
# Name: in_df, dtype: int64

# %%
df_k_2 = df_k[df_k['jumlah'] <= 2]
df_k_2.head()
# Out:
#                  kata  jumlah  in_df
# 7043  cnnindonesiacom       2      0
# 7044        loyalitas       2      1
# 7045           merlot       2      0
# 7046             bosq       2      0
# 7047             naba       2      0

# %%
df_k_2.in_df.value_counts()
# Out:
# 0    10773
# 1     3419
# Name: in_df, dtype: int64

# %%
words = list(df.lema)

w_rank = {}
for i,word in enumerate(words):
    w_rank[word] = i

WORDS = w_rank

# %%
import itertools
dict(itertools.islice(WORDS.items(), 10))
# Out:
# {'-an': 0,
#  '-anda': 1,
#  '-asi': 2,
#  '-da': 3,
#  '-el-': 4,
#  '-em-': 5,
#  '-er-': 6,
#  '-i': 7,
#  '-iah': 8,
#  '-if': 9}

# %%
import re
from collections import Counter

def words(text): return re.findall(r'\w+', text.lower())

def P(word): 
    "Probability of `word`."
    # use inverse of rank as proxy
    # returns 0 if the word isn't in the dictionary
    return - WORDS.get(word, 0)

def correction(word): 
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word): 
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words): 
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
candidates('rmah')
# Out:
# {'amah', 'mah', 'ramah', 'remah', 'riah', 'rimah', 'rumah'}

# %%
from google.colab import files
df_k_2.to_csv('stop.csv') 
files.download('stop.csv')

# %%
stopwords = list(df_k_2.kata)
stopwords
# Out:
# ['cnnindonesiacom',
#  'loyalitas',
#  'merlot',
#  'bosq',
#  'naba',
#  'ditendang',
#  'setrum',
#  'ukiran',
#  'lrtternyata',
#  '1438',
#  'cnnindonesia',
#  'hancurkanlah',
#  'muat',
#  'animasi',
#  'rokan',
#  'wahidin',
#  'under',
#  'bae',
#  'daeng',
#  'penyiksan',
#  'tanoe',
#  'dobel',
#  'dates',
#  'special',
#  'perlukah',
#  'cekrek',
#  'tetiba',
#  'belangnya',
#  'morning',
#  '91',
#  'cooper',
#  't3ror1sme',
#  'jagal',
#  'kering',
#  'httpsyoutubejdpmbdyvyx8',
#  'wasiat',
#  'atlasrubat',
#  'ciut',
#  'zohri',
#  'berupa',
#  'mahzulkan',
#  'person',
#  'dupa',
#  'diem2',
#  'koar',
#  'jemur',
#  'boys',
#  'mks',
#  'netanyahu',
#  'disangka',
#  'insyaa',
#  'alphard',
#  'tepok',
#  'hio',
#  'poly',
#  'diinfokan',
#  'jalin',
#  'jakartasurabaya',
#  'nigerian',
#  'terusir',
#  'hantavirus',
#  'terkejut',
#  'barakuda',
#  'dinaikkan',
#  'strong',
#  'dibesarbesarkan',
#  'lembab',
#  'marquez',
#  'penyedot',
#  'diselesaikan',
# ...
