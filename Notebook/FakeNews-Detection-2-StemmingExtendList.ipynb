# %%
from google.colab import drive
 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# 4/4AHefTyLGEtiRefI5HNDnpQtn4D5-lfKfVWsk6nJ-BsY2F-gvHC1QvY
# Mounted at /content/gdrive

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import numpy as np
import itertools
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, HashingVectorizer
from sklearn import metrics
import matplotlib.pyplot as plt

# %% [markdown]
# # **Data Exploration**

# %% [markdown]
# **1. Data Training**

# %%
df = pd.read_excel('/content/gdrive/My Drive/BDC SD/Salinan Data Latih BDC.xlsx')

# %%
df.head(10)
# Out:
#      ID  ...  nama file gambar
# 0    71  ...            71.jpg
# 1   461  ...           461.png
# 2   495  ...           495.png
# 3   550  ...           550.png
# 4   681  ...           681.jpg
# 5   736  ...           736.png
# 6  1161  ...          1161.png
# 7  1597  ...          1597.png
# 8  2098  ...          2098.jpg
# 9  2226  ...          2226.png
#
# [10 rows x 6 columns]

# %%
df.shape
# Out:
# (4231, 6)

# %%
df = df.drop(['tanggal', 'nama file gambar'], axis=1)

# %%
df = df.set_index('ID')

# %%
df.head(10)
# Out:
#       label  ...                                             narasi
# ID           ...
# 71        1  ...  A caller to a radio talk show recently shared ...
# 461       1  ...  Yth.Seluruh Anggota Grup Sesuai Instruksi Gube...
# 495       1  ...  Jokowi adalah presiden terbaik dlm sejarah ban...
# 550       1  ...  Maaf Mas2 dan Mbak2, ini bukan politik, tapi k...
# 681       1  ...        Kadrun kalo lihat foto ini panas dingin . .
# 736       1  ...  selamat siang teman teman fb ku semuanya🤩,cuma...
# 1161      1  ...  LIHATLAH MEREKA SUDAH MEMPERSIAPKAN DIRI DENGA...
# 1597      1  ...  Italia punya fasilitas perawatan kesehatan ter...
# 2098      1  ...  Polisi goblok. Bukanya cpet” d tolongin malah ...
# 2226      1  ...  Polisi china telah menganiaya wanita uighur le...
#
# [10 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4231 entries, 71 to 999860
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   4231 non-null   int64
#  1   judul   4231 non-null   object
#  2   narasi  4231 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 132.2+ KB

# %%
df['label'].value_counts()
# Out:
# 1    3465
# 0     766
# Name: label, dtype: int64

# %% [markdown]
# Dari label, terlihat data unbalanced karena label hoax(1) jauh lebih banyak daripada label 0.

# %% [markdown]
# Menggabungkan judul dan narasi menjadi kolom baru

# %%
df['total']=df['judul'] + ' ' + df['narasi']
df.head()
# Out:
#      label  ...                                              total
# ID          ...
# 71       1  ...  Pemakaian Masker Menyebabkan Penyakit Legionna...
# 461      1  ...  Instruksi Gubernur Jateng tentang penilangan  ...
# 495      1  ...  Foto Jim Rohn: Jokowi adalah presiden terbaik ...
# 550      1  ...  ini bukan politik, tapi kenyataan Pak Jokowi b...
# 681      1  ...  Foto Kadrun kalo lihat foto ini panas dingin K...
#
# [5 rows x 4 columns]

# %% [markdown]
# **2. Data Testing**

# %%
df_t = pd.read_excel('/content/gdrive/My Drive/BDC SD/Data Uji BDC.xlsx')
df_t.head()
# Out:
#        ID              tanggal  ... nama file gambar label
# 0  238057  2020-07-13 00:00:00  ...       238057.jpg     1
# 1  238158  2020-07-06 00:00:00  ...       238158.jpg     1
# 2  238865  2020-04-22 00:00:00  ...       238865.jpg     1
# 3  248298  2019-10-22 00:00:00  ...       248298.jpg     1
# 4  255176  2020-05-01 00:00:00  ...       255176.jpg     1
#
# [5 rows x 6 columns]

# %%
df_t['total']=df_t['judul'] + ' ' + df_t['narasi']
df_t = df_t.drop(['tanggal', 'nama file gambar'], axis=1)
df_t.head()
# Out:
#        ID  ...                                              total
# 0  238057  ...  Narasi Tito Karnavian Berideologi Komunis Kare...
# 1  238158  ...  Anies: Seberat beratnya Pekerjaan Akan terasa ...
# 2  238865  ...  Hindu di india Melemparkan Patung Buatan Merek...
# 3  248298  ...  RSCM Praktekkan Penyedotan Plug  Vena/Saluran ...
# 4  255176  ...  Permohonan Kelonggaran Angsuran ke OJK Untuk s...
#
# [5 rows x 5 columns]

# %%
df_t = df_t.set_index('ID')

# %% [markdown]
# # **Preprocessing Data**

# %%
import nltk
import re
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# !pip install Sastrawi
#stopwords removal
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
stop = StopWordRemoverFactory().get_stop_words()

#stemmer
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
# Out:
# Collecting Sastrawi
#   Downloading https://files.pythonhosted.org/packages/6f/4b/bab676953da3103003730b8fcdfadbdd20f333d4add10af949dd5c51e6ed/Sastrawi-1.0.1-py2.py3-none-any.whl (209kB)
#      |████████████████████████████████| 215kB 2.8MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
stemmer = factory.create_stemmer()

from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah', 'lg', 'deh', 'toh', 'piye', 'prettt', 'tak', 'sblm', 'dlm', 'sekedar'])
stop_words = list_stopwords

#preprocessing data training
for index, row in df.iterrows():
    filter_sentence = ''
    sentence = row['total']
    # Cleaning dengan regular expression
    sentence = re.sub(r'[^\w\s]', '', sentence)
    sentence = stemmer.stem(sentence)
    # Tokenization
    words = nltk.word_tokenize(sentence)
    # Menghilangkan stopwords
    words = [w for w in words if not w in stop_words]
    # Lower case
    for words in words:
        filter_sentence = filter_sentence  + ' ' + words.lower()
    
    df.loc[index, 'total'] = filter_sentence

#preprocessing data testing    
for index, row in df_t.iterrows():
    filter_sentence = ''
    sentence = row['total']
    # Cleaning dengan regular expression
    sentence = re.sub(r'[^\w\s]', '', sentence)
    sentence = stemmer.stem(sentence)
    # Tokenization
    words = nltk.word_tokenize(sentence)
    # Menghilangkan stopwords
    words = [w for w in words if not w in stop_words]
    # Lower case
    for words in words:
        filter_sentence = filter_sentence  + ' ' + words.lower()
    
    df_t.loc[index, 'total'] = filter_sentence

# %%
df.head()
# Out:
#      label  ...                                              total
# ID          ...
# 71       1  ...   pakai masker sakit legionnaires a caller to a...
# 461      1  ...   instruksi gubernur jateng tilang masker muka ...
# 495      1  ...   foto jim rohn jokowi presiden sejarah bangsa ...
# 550      1  ...   politik nyata jokowi hasil pulang 11000 trili...
# 681      1  ...   foto kadrun lihat foto panas dingin kadrun li...
#
# [5 rows x 4 columns]

# %%
#inisiasi x dan y
x_train = df['total']
y_train = df['label']

# %%
df_t.head()
# Out:
#                                                     judul  ...                                              total
# ID                                                         ...
# 238057  Narasi Tito Karnavian Berideologi Komunis Kare...  ...   narasi tito karnavian ideologi komunis sekola...
# 238158  Anies: Seberat beratnya Pekerjaan Akan terasa ...  ...   anies berat berat kerja asa ringan kerja bera...
# 238865  Hindu di india Melemparkan Patung Buatan Merek...  ...   hindu india lempar patung laut tolong corona ...
# 248298  RSCM Praktekkan Penyedotan Plug  Vena/Saluran ...  ...   rscm praktek sedot plug venasaluran darah rsc...
# 255176             Permohonan Kelonggaran Angsuran ke OJK  ...   mohon longgar angsur ojk dar info ansurancici...
#
# [5 rows x 4 columns]

# %%
x_test = df_t['total']
y_test = df_t['label']

# %% [markdown]
# # **Vectorizaton**

# %% [markdown]
# 1. TF-IDF Vectorization

# %%
# Initialize a TfidfVectorizer
tfidf_vectorizer=TfidfVectorizer(max_df=1.0)

#Fit and transform train set, transform test set
tfidf_train=tfidf_vectorizer.fit_transform(x_train) 
tfidf_test=tfidf_vectorizer.transform(x_test)

# %% [markdown]
# 2. Count Vectorizer

# %%
# Initialize a CountVectorizer
count_vectorizer = CountVectorizer()

#Fit and transform train set, transform test set
count_train = count_vectorizer.fit_transform(x_train)
count_test = count_vectorizer.transform(x_test)

# %% [markdown]
# # **Modelling**

# %% [markdown]
# 1. PASSIVE-AGGRESSIVE CLASSIFIER

# %%
from sklearn.metrics import f1_score
from sklearn.linear_model import PassiveAggressiveClassifier

# %%
# PASSIVE-AGGRESSIVE CLASSIFIER TF-IDF   

pac=PassiveAggressiveClassifier(max_iter=50)
pac.fit(tfidf_train,y_train)
#Predict on the test set
y_pred = pac.predict(tfidf_test)

#F1 Score
scoref1 = f1_score(y_test, y_pred)
print(f'F1 Score: {round(scoref1*100,2)}%')
# Out:
# F1 Score: 89.65%

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred, labels=[0,1])
print(confusion_matrix)
# Out:
# [[ 33  48]
#  [ 34 355]]

# %%
# PASSIVE-AGGRESSIVE CLASSIFIER Count

pac=PassiveAggressiveClassifier(max_iter=50)
pac.fit(count_train,y_train)

#Predict on the test set
y_pred=pac.predict(count_test)

scoref1c=f1_score(y_test, y_pred)
print(f'F1 score: {round(scoref1c*100,2)}%')
# Out:
# F1 score: 88.63%

# %% [markdown]
# 2. MULTINOMIAL NAIVE BAYES

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# %%
#Multinomial NB TF-IDF

# Create the list of alphas: alphas
alphas = np.arange(0, 1, 0.1)

# Define train_and_predict()
def train_and_predict(alpha, tfidf_train, y_train, tfidf_test, y_test):
    # Instantiate the classifier: nb_classifier
    nb_classifier = MultinomialNB(alpha=alpha)
    # Fit to the training data
    nb_classifier.fit(tfidf_train, y_train)
    # Predict the labels: pred
    pred = nb_classifier.predict(tfidf_test)
    # Compute accuracy: score
    score = metrics.f1_score(y_test, pred)
    return score

# Iterate over the alphas and print the corresponding score
for alpha in alphas:
    print('Alpha: ', alpha)
    print('Score: ', train_and_predict(alpha, tfidf_train, y_train, tfidf_test, y_test))
    print()
# Out:
# Alpha:  0.0
# Score:  0.9029126213592233
#
# Alpha:  0.1
# Score:  0.9146919431279622
#
# Alpha:  0.2
# Score:  0.9129411764705883
#
# Alpha:  0.30000000000000004
# Score:  0.9088785046728971
#
# Alpha:  0.4
# Score:  0.9057043073341093
#
# Alpha:  0.5
# Score:  0.9057043073341093
#
# Alpha:  0.6000000000000001
# Score:  0.9057043073341093
#
# Alpha:  0.7000000000000001
# Score:  0.9057043073341093
#
# Alpha:  0.8
# Score:  0.9057043073341093
#
# Alpha:  0.9
# Score:  0.9057043073341093
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(tfidf_train, y_train)
Accuracy = logreg.score(tfidf_test, y_test)

print(Accuracy*100)
# Out:
# 85.1063829787234

# %%
hasil = pd.DataFrame()
